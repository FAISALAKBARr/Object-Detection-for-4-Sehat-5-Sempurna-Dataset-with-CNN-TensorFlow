# %%
#Versi 2
#Total Dataset: 5000
#Splitting Dataset 70% Train, 15% Test, 15% Validation

import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Dataset paths
base_dir = '/kaggle/input/data-4-sehat-5-sempurna/Dataset'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validasi')
test_dir = os.path.join(base_dir, 'test')

# Print dataset distribution
def print_dataset_info():
    # categories = ['karbohidrat', 'protein', 'buah', 'sayur', 'minuman']
    categories = ['buah', 'karbohidrat', 'minuman', 'protein', 'sayur']
    for split, directory in [('Training', train_dir), ('Validation', validation_dir), ('Test', test_dir)]:
        print(f"\n{split} Dataset Distribution:")
        total = 0
        for category in categories:
            path = os.path.join(directory, category)
            count = len(os.listdir(path)) if os.path.exists(path) else 0
            total += count
            print(f'{category}: {count} images')
        print(f'Total: {total} images')

print_dataset_info()

# Enhanced Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    # rotation_range=30,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # zoom_range=0.2,
    # horizontal_flip=True,
    # # vertical_flip=False,
    # fill_mode='nearest',
    # brightness_range=[0.8, 1.2],
    # preprocessing_function=lambda x: tf.image.random_contrast(x, 0.8, 1.2),
    ##tambahan
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    preprocessing_function=lambda x: tf.image.random_contrast(x, 0.8, 1.2)
)

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Image size and batch configuration
IMG_SIZE = 224  # Increased image size
BATCH_SIZE = 16 # Smaller batch size for better generalization

# Create generators with class balancing
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

validation_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

#Callback
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        train_accuracy = logs.get('accuracy')
        val_accuracy = logs.get('val_accuracy')
        
        # Check if metrics exist
        if train_accuracy is not None and val_accuracy is not None:
            accuracy_gap = abs(train_accuracy - val_accuracy)
            
            # Check if accuracy >= 95% and gap < 15%
            if train_accuracy >= 0.96 and accuracy_gap <= 0.15:
                print(f"\nPelatihan dihentikan pada epoch {epoch + 1}:")
                print(f"Akurasi training mencapai {train_accuracy:.2f} dan gap dengan validation {accuracy_gap:.2f} (> 0.15)")
                self.model.stop_training = True

# Callback Definition
callbacks = myCallback()
# Improved CNN Architecture
def create_improved_model():
    model = tf.keras.Sequential([
        # First Block - Initial features extraction
        tf.keras.layers.Conv2D(64, (3, 3), padding='same', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(64, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.3),

        # Second Block - Increased complexity
        tf.keras.layers.Conv2D(128, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(128, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.3),

        # Third Block - Deep feature extraction
        tf.keras.layers.Conv2D(256, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(256, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.4),

        # Fourth Block - Final feature extraction
        tf.keras.layers.Conv2D(512, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Conv2D(512, (3, 3), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.4),

        # Classifier
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(256),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Activation('relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(5, activation='softmax')
    ])
    return model

# Learning Rate Schedule
initial_learning_rate = 1e-4
def lr_schedule(epoch):
    return initial_learning_rate * (0.1 ** (epoch // 30))

# Custom Callback for monitoring training
class TrainingMonitor(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if (epoch + 1) % 5 == 0:
            print(f"\nEpoch {epoch + 1} Summary:")
            print(f"Training Accuracy: {logs.get('accuracy'):.4f}")
            print(f"Validation Accuracy: {logs.get('val_accuracy'):.4f}")
            print(f"Training Loss: {logs.get('loss'):.4f}")
            print(f"Validation Loss: {logs.get('val_loss'):.4f}")
            print(f"Learning Rate: {self.model.optimizer.learning_rate.numpy():.2e}")

# Create and compile model
model = create_improved_model()
optimizer = tf.keras.optimizers.Adam(learning_rate=initial_learning_rate)
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
EPOCHS = 114
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    callbacks = [callbacks]
)

# Plot training history
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Accuracy plot
    ax1.plot(history.history['accuracy'], label='Training')
    ax1.plot(history.history['val_accuracy'], label='Validation')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)
    
    # Loss plot
    ax2.plot(history.history['loss'], label='Training')
    ax2.plot(history.history['val_loss'], label='Validation')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)
    
    plt.tight_layout()
    plt.show()

plot_training_history(history)

# Model evaluation
def evaluate_model(model, generator, set_name="Test"):
    # Predictions
    predictions = model.predict(generator, verbose=1)
    y_pred = np.argmax(predictions, axis=1)
    y_true = generator.classes
    
    # Get class names
    class_names = list(generator.class_indices.keys())
    
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title(f'Confusion Matrix ({set_name} Set)')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()
    
    # Classification Report
    print(f"\nClassification Report ({set_name} Set):")
    print(classification_report(y_true, y_pred, target_names=class_names))
    
    # Overall Metrics
    loss, accuracy = model.evaluate(generator, verbose=0)
    print(f"\n{set_name} Set Accuracy: {accuracy:.4f}")
    print(f"{set_name} Set Loss: {loss:.4f}")

# Evaluate on validation and test sets
print("\nTrain Set Evaluation:")
evaluate_model(model, train_generator, "Train")

print("\nValidation Set Evaluation:")
evaluate_model(model, validation_generator, "Validation")

print("\nTest Set Evaluation:")
evaluate_model(model, test_generator, "Test")

# Save model and history
model.save('/kaggle/working/FINAL_MODEL.h5')
history_df = pd.DataFrame(history.history)
history_df.to_csv('/kaggle/working/training_history.csv')
print("\nModel and training history saved successfully!")
# Out:
# Training Dataset Distribution:
# buah: 700 images
# karbohidrat: 700 images
# minuman: 700 images
# protein: 700 images
# sayur: 700 images
# Total: 3500 images
#
# Validation Dataset Distribution:
# buah: 150 images
# karbohidrat: 150 images
# minuman: 150 images
# protein: 150 images
# sayur: 150 images
# Total: 750 images
#
# Test Dataset Distribution:
# buah: 150 images
# karbohidrat: 150 images
# minuman: 150 images
# protein: 150 images
# sayur: 150 images
# Total: 750 images
# Found 3500 images belonging to 5 classes.
# Found 750 images belonging to 5 classes.
# Found 750 images belonging to 5 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/114
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733244869.319947     153 service.cc:145] XLA service 0x7c0aa0009e50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733244869.320057     153 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   1/219 ━━━━━━━━━━━━━━━━━━━━ 2:02:36 34s/step - accuracy: 0.1875 - loss: 2.5565
# I0000 00:00:1733244892.736201     153 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 164s 596ms/step - accuracy: 0.2679 - loss: 2.0467 - val_accuracy: 0.2000 - val_loss: 3.6559
# Epoch 2/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 386ms/step - accuracy: 0.3907 - loss: 1.5809 - val_accuracy: 0.2560 - val_loss: 2.5597
# Epoch 3/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 388ms/step - accuracy: 0.4488 - loss: 1.4409 - val_accuracy: 0.3680 - val_loss: 1.6589
# Epoch 4/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 383ms/step - accuracy: 0.4806 - loss: 1.3664 - val_accuracy: 0.3680 - val_loss: 1.6770
# Epoch 5/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 377ms/step - accuracy: 0.4704 - loss: 1.3938 - val_accuracy: 0.4320 - val_loss: 1.3728
# Epoch 6/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 394ms/step - accuracy: 0.5049 - loss: 1.3389 - val_accuracy: 0.4880 - val_loss: 1.2462
# Epoch 7/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 368ms/step - accuracy: 0.5181 - loss: 1.2798 - val_accuracy: 0.5853 - val_loss: 1.0931
# Epoch 8/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 387ms/step - accuracy: 0.5086 - loss: 1.2678 - val_accuracy: 0.5773 - val_loss: 1.0860
# Epoch 9/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 382ms/step - accuracy: 0.5358 - loss: 1.2090 - val_accuracy: 0.6480 - val_loss: 0.9259
# Epoch 10/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 93s 415ms/step - accuracy: 0.5393 - loss: 1.2228 - val_accuracy: 0.6320 - val_loss: 0.9138
# Epoch 11/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 382ms/step - accuracy: 0.5525 - loss: 1.1518 - val_accuracy: 0.5533 - val_loss: 1.2809
# Epoch 12/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 378ms/step - accuracy: 0.5796 - loss: 1.1548 - val_accuracy: 0.6720 - val_loss: 0.8226
# Epoch 13/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 385ms/step - accuracy: 0.5937 - loss: 1.0670 - val_accuracy: 0.6333 - val_loss: 0.9787
# Epoch 14/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 82s 364ms/step - accuracy: 0.5926 - loss: 1.0844 - val_accuracy: 0.6587 - val_loss: 0.9227
# Epoch 15/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 81s 360ms/step - accuracy: 0.5878 - loss: 1.0797 - val_accuracy: 0.6267 - val_loss: 0.9977
# Epoch 16/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 369ms/step - accuracy: 0.6004 - loss: 1.0586 - val_accuracy: 0.6613 - val_loss: 0.8659
# Epoch 17/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 82s 366ms/step - accuracy: 0.6196 - loss: 1.0200 - val_accuracy: 0.6773 - val_loss: 0.8458
# Epoch 18/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 393ms/step - accuracy: 0.6138 - loss: 1.0265 - val_accuracy: 0.6587 - val_loss: 0.9143
# Epoch 19/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 378ms/step - accuracy: 0.6206 - loss: 0.9864 - val_accuracy: 0.6880 - val_loss: 0.8817
# Epoch 20/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 385ms/step - accuracy: 0.6163 - loss: 0.9868 - val_accuracy: 0.6613 - val_loss: 0.8466
# Epoch 21/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 377ms/step - accuracy: 0.6365 - loss: 0.9824 - val_accuracy: 0.6600 - val_loss: 0.9640
# Epoch 22/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 375ms/step - accuracy: 0.6423 - loss: 0.9315 - val_accuracy: 0.6880 - val_loss: 0.8810
# Epoch 23/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 368ms/step - accuracy: 0.6536 - loss: 0.9182 - val_accuracy: 0.6960 - val_loss: 0.7724
# Epoch 24/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 82s 366ms/step - accuracy: 0.6490 - loss: 0.9101 - val_accuracy: 0.7013 - val_loss: 0.8631
# Epoch 25/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 81s 362ms/step - accuracy: 0.6619 - loss: 0.8872 - val_accuracy: 0.6227 - val_loss: 1.0368
# Epoch 26/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 371ms/step - accuracy: 0.6725 - loss: 0.8702 - val_accuracy: 0.5653 - val_loss: 1.2296
# Epoch 27/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 82s 367ms/step - accuracy: 0.6570 - loss: 0.8746 - val_accuracy: 0.7187 - val_loss: 0.7752
# Epoch 28/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 378ms/step - accuracy: 0.6771 - loss: 0.8633 - val_accuracy: 0.7253 - val_loss: 0.7055
# Epoch 29/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 372ms/step - accuracy: 0.6767 - loss: 0.8729 - val_accuracy: 0.6400 - val_loss: 1.0454
# Epoch 30/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 377ms/step - accuracy: 0.6733 - loss: 0.8848 - val_accuracy: 0.6747 - val_loss: 0.9327
# Epoch 31/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 379ms/step - accuracy: 0.7015 - loss: 0.8086 - val_accuracy: 0.7120 - val_loss: 0.7622
# Epoch 32/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 89s 398ms/step - accuracy: 0.6951 - loss: 0.8224 - val_accuracy: 0.6813 - val_loss: 0.9303
# Epoch 33/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 394ms/step - accuracy: 0.6878 - loss: 0.8389 - val_accuracy: 0.6840 - val_loss: 0.8723
# Epoch 34/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 394ms/step - accuracy: 0.7050 - loss: 0.7984 - val_accuracy: 0.6880 - val_loss: 0.8779
# Epoch 35/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 390ms/step - accuracy: 0.6930 - loss: 0.8397 - val_accuracy: 0.7453 - val_loss: 0.6947
# Epoch 36/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 388ms/step - accuracy: 0.7050 - loss: 0.7786 - val_accuracy: 0.7680 - val_loss: 0.6546
# Epoch 37/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.7059 - loss: 0.8103 - val_accuracy: 0.7267 - val_loss: 0.7031
# Epoch 38/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 393ms/step - accuracy: 0.7090 - loss: 0.8028 - val_accuracy: 0.7480 - val_loss: 0.6686
# Epoch 39/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 384ms/step - accuracy: 0.7256 - loss: 0.7443 - val_accuracy: 0.7253 - val_loss: 0.7345
# Epoch 40/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.7176 - loss: 0.7549 - val_accuracy: 0.7333 - val_loss: 0.7677
# Epoch 41/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 372ms/step - accuracy: 0.7189 - loss: 0.7490 - val_accuracy: 0.7587 - val_loss: 0.6794
# Epoch 42/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 377ms/step - accuracy: 0.7251 - loss: 0.7166 - val_accuracy: 0.7533 - val_loss: 0.6909
# Epoch 43/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 370ms/step - accuracy: 0.7222 - loss: 0.7410 - val_accuracy: 0.7173 - val_loss: 0.8183
# Epoch 44/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 376ms/step - accuracy: 0.7317 - loss: 0.7126 - val_accuracy: 0.7920 - val_loss: 0.5831
# Epoch 45/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 370ms/step - accuracy: 0.7601 - loss: 0.6783 - val_accuracy: 0.7800 - val_loss: 0.6123
# Epoch 46/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 379ms/step - accuracy: 0.7432 - loss: 0.6855 - val_accuracy: 0.7600 - val_loss: 0.7083
# Epoch 47/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 379ms/step - accuracy: 0.7376 - loss: 0.7202 - val_accuracy: 0.7600 - val_loss: 0.6554
# Epoch 48/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 384ms/step - accuracy: 0.7422 - loss: 0.6688 - val_accuracy: 0.7093 - val_loss: 0.8899
# Epoch 49/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 379ms/step - accuracy: 0.7526 - loss: 0.6713 - val_accuracy: 0.7413 - val_loss: 0.7981
# Epoch 50/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 382ms/step - accuracy: 0.7502 - loss: 0.6653 - val_accuracy: 0.7107 - val_loss: 0.9056
# Epoch 51/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 390ms/step - accuracy: 0.7569 - loss: 0.6338 - val_accuracy: 0.7213 - val_loss: 0.8655
# Epoch 52/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 381ms/step - accuracy: 0.7433 - loss: 0.6671 - val_accuracy: 0.7547 - val_loss: 0.7299
# Epoch 53/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 392ms/step - accuracy: 0.7589 - loss: 0.6468 - val_accuracy: 0.7733 - val_loss: 0.6484
# Epoch 54/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 392ms/step - accuracy: 0.7703 - loss: 0.6195 - val_accuracy: 0.7813 - val_loss: 0.7215
# Epoch 55/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 89s 394ms/step - accuracy: 0.7669 - loss: 0.6317 - val_accuracy: 0.7693 - val_loss: 0.7006
# Epoch 56/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 394ms/step - accuracy: 0.7524 - loss: 0.6295 - val_accuracy: 0.7773 - val_loss: 0.6340
# Epoch 57/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 90s 399ms/step - accuracy: 0.7835 - loss: 0.5874 - val_accuracy: 0.7827 - val_loss: 0.5867
# Epoch 58/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 89s 396ms/step - accuracy: 0.7716 - loss: 0.6265 - val_accuracy: 0.7760 - val_loss: 0.6952
# Epoch 59/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 89s 398ms/step - accuracy: 0.7871 - loss: 0.5768 - val_accuracy: 0.7333 - val_loss: 0.8432
# Epoch 60/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 390ms/step - accuracy: 0.7773 - loss: 0.6063 - val_accuracy: 0.7987 - val_loss: 0.6252
# Epoch 61/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 391ms/step - accuracy: 0.7826 - loss: 0.5931 - val_accuracy: 0.7707 - val_loss: 0.7087
# Epoch 62/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 387ms/step - accuracy: 0.7858 - loss: 0.6212 - val_accuracy: 0.7867 - val_loss: 0.6578
# Epoch 63/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 386ms/step - accuracy: 0.7840 - loss: 0.5992 - val_accuracy: 0.7560 - val_loss: 0.7254
# Epoch 64/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 385ms/step - accuracy: 0.7956 - loss: 0.5633 - val_accuracy: 0.6707 - val_loss: 0.9484
# Epoch 65/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 383ms/step - accuracy: 0.7964 - loss: 0.5593 - val_accuracy: 0.7480 - val_loss: 0.7683
# Epoch 66/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 390ms/step - accuracy: 0.8030 - loss: 0.5677 - val_accuracy: 0.7747 - val_loss: 0.6967
# Epoch 67/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 391ms/step - accuracy: 0.7871 - loss: 0.5655 - val_accuracy: 0.7813 - val_loss: 0.6661
# Epoch 68/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 88s 393ms/step - accuracy: 0.8007 - loss: 0.5769 - val_accuracy: 0.8027 - val_loss: 0.5722
# Epoch 69/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 386ms/step - accuracy: 0.7980 - loss: 0.5620 - val_accuracy: 0.8173 - val_loss: 0.5543
# Epoch 70/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 383ms/step - accuracy: 0.8082 - loss: 0.5274 - val_accuracy: 0.7600 - val_loss: 0.7360
# Epoch 71/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 384ms/step - accuracy: 0.8217 - loss: 0.5170 - val_accuracy: 0.7960 - val_loss: 0.6364
# Epoch 72/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 379ms/step - accuracy: 0.8136 - loss: 0.5220 - val_accuracy: 0.8107 - val_loss: 0.5512
# Epoch 73/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 382ms/step - accuracy: 0.8189 - loss: 0.5164 - val_accuracy: 0.8213 - val_loss: 0.5334
# Epoch 74/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 383ms/step - accuracy: 0.8223 - loss: 0.4881 - val_accuracy: 0.7040 - val_loss: 0.9147
# Epoch 75/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 376ms/step - accuracy: 0.8251 - loss: 0.4974 - val_accuracy: 0.7827 - val_loss: 0.7047
# Epoch 76/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 375ms/step - accuracy: 0.8211 - loss: 0.5035 - val_accuracy: 0.7907 - val_loss: 0.6135
# Epoch 77/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 371ms/step - accuracy: 0.8164 - loss: 0.5125 - val_accuracy: 0.7573 - val_loss: 0.7079
# Epoch 78/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 381ms/step - accuracy: 0.8217 - loss: 0.4964 - val_accuracy: 0.7987 - val_loss: 0.6051
# Epoch 79/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 377ms/step - accuracy: 0.8190 - loss: 0.5021 - val_accuracy: 0.8413 - val_loss: 0.4694
# Epoch 80/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 373ms/step - accuracy: 0.8318 - loss: 0.4800 - val_accuracy: 0.8133 - val_loss: 0.5245
# Epoch 81/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 373ms/step - accuracy: 0.8251 - loss: 0.4923 - val_accuracy: 0.8093 - val_loss: 0.6485
# Epoch 82/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 371ms/step - accuracy: 0.8169 - loss: 0.5019 - val_accuracy: 0.7853 - val_loss: 0.6001
# Epoch 83/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 374ms/step - accuracy: 0.8279 - loss: 0.4955 - val_accuracy: 0.8040 - val_loss: 0.5935
# Epoch 84/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 372ms/step - accuracy: 0.8212 - loss: 0.4705 - val_accuracy: 0.7880 - val_loss: 0.6242
# Epoch 85/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 373ms/step - accuracy: 0.8199 - loss: 0.5070 - val_accuracy: 0.7813 - val_loss: 0.6604
# Epoch 86/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.8275 - loss: 0.4874 - val_accuracy: 0.7947 - val_loss: 0.6759
# Epoch 87/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 87s 390ms/step - accuracy: 0.8358 - loss: 0.4760 - val_accuracy: 0.7787 - val_loss: 0.6920
# Epoch 88/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 376ms/step - accuracy: 0.8371 - loss: 0.4434 - val_accuracy: 0.7707 - val_loss: 0.7993
# Epoch 89/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 374ms/step - accuracy: 0.8375 - loss: 0.4383 - val_accuracy: 0.7973 - val_loss: 0.6038
# Epoch 90/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 377ms/step - accuracy: 0.8276 - loss: 0.4756 - val_accuracy: 0.7573 - val_loss: 0.7775
# Epoch 91/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.8408 - loss: 0.4541 - val_accuracy: 0.7560 - val_loss: 0.7712
# Epoch 92/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 384ms/step - accuracy: 0.8499 - loss: 0.4040 - val_accuracy: 0.8133 - val_loss: 0.6223
# Epoch 93/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 384ms/step - accuracy: 0.8509 - loss: 0.4150 - val_accuracy: 0.8147 - val_loss: 0.5842
# Epoch 94/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 384ms/step - accuracy: 0.8288 - loss: 0.4606 - val_accuracy: 0.8200 - val_loss: 0.4918
# Epoch 95/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 386ms/step - accuracy: 0.8485 - loss: 0.4383 - val_accuracy: 0.7093 - val_loss: 0.8520
# Epoch 96/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 373ms/step - accuracy: 0.8413 - loss: 0.4473 - val_accuracy: 0.8467 - val_loss: 0.4652
# Epoch 97/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 376ms/step - accuracy: 0.8409 - loss: 0.4281 - val_accuracy: 0.8400 - val_loss: 0.4746
# Epoch 98/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 374ms/step - accuracy: 0.8699 - loss: 0.3674 - val_accuracy: 0.8133 - val_loss: 0.5612
# Epoch 99/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 83s 372ms/step - accuracy: 0.8469 - loss: 0.4210 - val_accuracy: 0.7653 - val_loss: 0.7404
# Epoch 100/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 385ms/step - accuracy: 0.8420 - loss: 0.4274 - val_accuracy: 0.8107 - val_loss: 0.5971
# Epoch 101/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 381ms/step - accuracy: 0.8424 - loss: 0.4306 - val_accuracy: 0.8413 - val_loss: 0.5121
# Epoch 102/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 382ms/step - accuracy: 0.8407 - loss: 0.4578 - val_accuracy: 0.8000 - val_loss: 0.6088
# Epoch 103/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 381ms/step - accuracy: 0.8676 - loss: 0.3981 - val_accuracy: 0.8533 - val_loss: 0.4785
# Epoch 104/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.8490 - loss: 0.4128 - val_accuracy: 0.7747 - val_loss: 0.8209
# Epoch 105/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 383ms/step - accuracy: 0.8693 - loss: 0.3892 - val_accuracy: 0.8133 - val_loss: 0.6171
# Epoch 106/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 379ms/step - accuracy: 0.8594 - loss: 0.3917 - val_accuracy: 0.7827 - val_loss: 0.7228
# Epoch 107/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 378ms/step - accuracy: 0.8574 - loss: 0.3909 - val_accuracy: 0.8173 - val_loss: 0.5869
# Epoch 108/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 375ms/step - accuracy: 0.8536 - loss: 0.3948 - val_accuracy: 0.8240 - val_loss: 0.5608
# Epoch 109/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 376ms/step - accuracy: 0.8704 - loss: 0.3762 - val_accuracy: 0.8453 - val_loss: 0.4783
# Epoch 110/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.8776 - loss: 0.3451 - val_accuracy: 0.7880 - val_loss: 0.6120
# Epoch 111/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 86s 383ms/step - accuracy: 0.8544 - loss: 0.3816 - val_accuracy: 0.8520 - val_loss: 0.4852
# Epoch 112/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 84s 375ms/step - accuracy: 0.8519 - loss: 0.4274 - val_accuracy: 0.7480 - val_loss: 0.8907
# Epoch 113/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.8613 - loss: 0.3800 - val_accuracy: 0.8227 - val_loss: 0.5131
# Epoch 114/114
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 85s 380ms/step - accuracy: 0.8573 - loss: 0.3920 - val_accuracy: 0.8160 - val_loss: 0.5504
# Train Set Evaluation:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 67s 303ms/step
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         buah       0.19      0.17      0.18       700
#  karbohidrat       0.20      0.22      0.21       700
#      minuman       0.19      0.20      0.20       700
#      protein       0.20      0.23      0.21       700
#        sayur       0.20      0.17      0.18       700
#
#     accuracy                           0.20      3500
#    macro avg       0.20      0.20      0.20      3500
# weighted avg       0.20      0.20      0.20      3500
#
#
# Train Set Accuracy: 0.9054
# Train Set Loss: 0.2817
#
# Validation Set Evaluation:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step
# Classification Report (Validation Set):
#               precision    recall  f1-score   support
#
#         buah       0.77      0.82      0.80       150
#  karbohidrat       0.76      0.77      0.76       150
#      minuman       0.93      0.97      0.95       150
#      protein       0.73      0.85      0.79       150
#        sayur       0.93      0.68      0.78       150
#
#     accuracy                           0.82       750
#    macro avg       0.82      0.82      0.82       750
# weighted avg       0.82      0.82      0.82       750
#
#
# Validation Set Accuracy: 0.8160
# Validation Set Loss: 0.5504
#
# Test Set Evaluation:
#  2/47 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#         buah       0.79      0.84      0.81       150
#  karbohidrat       0.78      0.86      0.82       150
#      minuman       0.93      0.97      0.95       150
#      protein       0.79      0.82      0.80       150
#        sayur       0.90      0.67      0.77       150
#
#     accuracy                           0.83       750
#    macro avg       0.84      0.83      0.83       750
# weighted avg       0.84      0.83      0.83       750
#
#
# Test Set Accuracy: 0.8320
# Test Set Loss: 0.5199
#
# Model and training history saved successfully!
